# %%
import pandas as pd
import numpy as np
from scipy.linalg import expm, logm
from scipy.stats import norm
import statsmodels.api as sm
from scipy import integrate
# %matplotlib inline

# %%
# %%capture
from tqdm.notebook import trange, tqdm
tqdm().pandas()

# %% [markdown]
# The computation of the matrix exponential is performed using the Pade approximation:
#
# Reference:
#
# Awad H. Al-Mohy and Nicholas J. Higham (2009) “A New Scaling and Squaring Algorithm for the Matrix Exponential.” SIAM Journal on Matrix Analysis and Applications. 31 (3). pp. 970-989. ISSN 1095-7162

# %% [markdown]
# ## Loading income data
# **Dataset**: rfamxxxx.csv
#
# **Years**: 1998 to 2012 (only even years)
#
# **Variables**:
# - *ANNO*: Year
# - *NQUEST*: Household ID
# - *Y1*: Net disposable income (w/o financial assets)
# - *Y2*: Net disposable income
#
# **Note**: data contain a currency shift from thousands of Italian Lire (until 2000) to Euro (from 2002) (1 Euro = 1936.27 Italian Lire).

# %%
years = [1998, 2000, 2002, 2004, 2006, 2008, 2010, 2012]
rfam = []
for year in years:
    print(year, end=' ')
    df = pd.read_csv(f'data.nosync/rfam{year}.csv')
    # convert the Italian Lire to Euro for years 1998 and 2000
    if year in [1998, 2000]:
        df['Y2'] = df['Y2']*1000/1936.27
        df['Y1'] = df['Y1']*1000/1936.27
    # rename income to Y_xxxx
    #df.rename(columns={'Y2':f'Y'}, inplace=True)
    # fix the lower-case header for 2008 and 2012
    if year in [2008, 2012]:
        df.rename(columns={'nquest':'NQUEST'}, inplace=True)
    # filter only columns of interest
    df = df[['ANNO','NQUEST','Y1','Y2']]
    rfam.append(df)
rfam = pd.concat(rfam)
# Out:
# 1998 2000 2002 2004 2006 2008 2010 2012

# %%
rfam
# Out:
#       ANNO  NQUEST            Y1            Y2
# 0     1998      34  80050.819359  79761.603495
# 1     1998     123   6197.482789   1323.722054
# 2     1998     173  20761.567343  21034.256586
# 3     1998     304  12911.422477  13820.386620
# 4     1998     325  15803.581112  16236.758806
# ...    ...     ...           ...           ...
# 8146  2012  889749  21778.000000  21956.020998
# 8147  2012  889750  14800.000000  14925.801505
# 8148  2012  889751  26000.000000  26178.020998
# 8149  2012  889752  23100.000000  23131.980055
# 8150  2012  889753  44600.000000  44754.284865
#
# [63018 rows x 4 columns]

# %%
# descriptive stats for the original dataset
rfam[['Y1','Y2']].describe()
# Out:
#                  Y1            Y2
# count  6.301800e+04  6.301800e+04
# mean   2.974698e+04  3.018494e+04
# std    2.340649e+04  2.426811e+04
# min   -4.338238e+04 -4.157511e+04
# 25%    1.598792e+04  1.601016e+04
# 50%    2.460000e+04  2.482162e+04
# 75%    3.760000e+04  3.801351e+04
# max    1.024568e+06  1.022617e+06

# %%
rfam[(rfam['Y1']<0)|(rfam['Y2']<0)]
# Out:
#       ANNO  NQUEST            Y1            Y2
# 50    1998    4370 -43382.379524 -39084.425209
# 513   1998   29421 -13796.115387 -13796.115387
# 1007  1998   34224    -68.370257    352.868994
# 4099  1998  505327 -39297.205452 -39669.054419
# 4279  1998  505782  -8890.723463  -6432.737098
# 4657  1998  506714 -19701.663105 -18672.880962
# 700   2000   33781   1394.433628   -201.521482
# 4002  2000  611518   1859.244837   -693.085159
# 897   2004   91043  -5705.949686  -5693.503837
# 1313  2004  506132  -6400.000000  -6214.114000
# 1366  2004  506647  -8500.000000  -8412.879054
# 5089  2004  683364 -41600.000000 -41575.108300
# 2609  2006  678264  -8700.000000  -8642.962575
# 4577  2008  801901   3600.000000    -49.366000
# 5799  2008  812007   7200.000000  -5431.449600
# 4488  2010  825175   -700.000000   -696.833972
# 6535  2012  881114  -1000.000000  -1000.000000

# %%
# remove households with negative Y2
neg_nquest = rfam[(rfam['Y2']<0)]['NQUEST']
rfam = rfam[~rfam['NQUEST'].isin(neg_nquest)]
rfam
# Out:
#       ANNO  NQUEST            Y1            Y2
# 0     1998      34  80050.819359  79761.603495
# 1     1998     123   6197.482789   1323.722054
# 2     1998     173  20761.567343  21034.256586
# 3     1998     304  12911.422477  13820.386620
# 4     1998     325  15803.581112  16236.758806
# ...    ...     ...           ...           ...
# 8146  2012  889749  21778.000000  21956.020998
# 8147  2012  889750  14800.000000  14925.801505
# 8148  2012  889751  26000.000000  26178.020998
# 8149  2012  889752  23100.000000  23131.980055
# 8150  2012  889753  44600.000000  44754.284865
#
# [62970 rows x 4 columns]

# %% [markdown]
# ## Load info dataset
#
# **Dataset**: compxxxx.csv
#
# **Variables**:
# - *ANNO*: year
# - *NQUEST*: Household ID
# - *NCOMP*: Number of household members
# - *AREA3*: 1=North, 2=Centre, 3=South and Islands
# - *SESSO*: Sex
# - *ETA*: Age(years)
# - *ETA5*: Age groups:
#     - 1 = up to 30 years
#     - 2 = from 31 to 40 years
#     - 3 = from 41 to 50 years
#     - 4 = from 51 to 65 years
#     - 5 = more than 65 years
# - *STUDIO*: Educational qualification:
#     - 1 = none
#     - 2 = elementary school
#     - 3 = middle school
#     - 4 = high school
#     - 5 = bachelor’s degree
#     - 6 = post-graduate qualification.

# %%
cols = ['ANNO','NQUEST','NCOMP','AREA3']
comp = []
for year in years:
    print(year, end=' ')
    df = pd.read_csv(f'data.nosync/comp{year}.csv')
    # fix the lower-case header for 2012
    if year in [2012]:
        df.rename(columns={'nquest':'NQUEST'}, inplace=True)
    # create the dataset with the value counts of the Age group
    A5 = df.groupby('NQUEST')['ETA5'].value_counts().to_frame().rename(columns={'ETA5':'COUNT'}).reset_index()
    A5 = pd.pivot_table(A5, values='COUNT', index='NQUEST', columns='ETA5')
    A5.columns = ['A'+str(x+1) for x in range(5)]
    A5.reset_index(inplace=True)
    A5 = A5.fillna(0).astype(dtype='int')
    # filter only columns of interest and drop duplicates
    df = df[cols].drop_duplicates()
    if len(df)-len(A5):
        print('ERROR while merging A5 with df')
    # join df with A5
    df = pd.merge(df, A5, how='left', on='NQUEST')
    # join datasets
    comp.append(df)
comp = pd.concat(comp)
# Out:
# 1998 2000 2002 2004 2006 2008 2010 2012

# %%
comp
# Out:
#       ANNO  NQUEST  NCOMP  AREA3  A1  A2  A3  A4  A5
# 0     1998      34      4      1   2   0   0   2   0
# 1     1998     123      4      3   2   0   0   2   0
# 2     1998     173      4      3   2   0   2   0   0
# 3     1998     304      3      3   1   2   0   0   0
# 4     1998     325      2      1   0   1   0   1   0
# ...    ...     ...    ...    ...  ..  ..  ..  ..  ..
# 8146  2012  889749      3      3   1   0   0   0   2
# 8147  2012  889750      1      1   1   0   0   0   0
# 8148  2012  889751      2      1   2   0   0   0   0
# 8149  2012  889752      4      3   2   0   0   2   0
# 8150  2012  889753      3      3   1   0   0   0   2
#
# [63018 rows x 9 columns]

# %% [markdown]
# ## Load poverty lines

# %%
pov = pd.read_csv('data.nosync/poverty lines.csv')
# convert the Italian Lire to Euro for years before 2000
pov.loc[:,'1997':'2000'] = pov.loc[:,'1997':'2000']/1936.27
pov = pov.set_index('NCOMP').unstack().to_frame().reset_index()
pov.columns = ['ANNO','COMP','Yp']
pov['Yp'] = pov['Yp']*12
pov['ANNO'] = pov['ANNO'].astype(dtype='int')
# drop 1997 observations
pov = pov[pov['ANNO']>1997].reset_index(drop=True)
# compute scale factor for income across number of components
pov['Yscale'] = (pov.set_index('ANNO')['Yp']/pov.groupby('ANNO')['Yp'].first()).reset_index(drop=True)
# compute scale factor for income over time
time_scale = (pov.groupby('ANNO')['Yp'].first()/pov.groupby('ANNO')['Yp'].first().loc[1998]).to_frame()
time_scale.columns = ['Tscale']
pov = pov.merge(time_scale, how='left', left_on=['ANNO'], right_index=True)
pov
# Out:
#      ANNO  COMP            Yp    Yscale    Tscale
# 0    1998     1   5479.498210  1.000000  1.000000
# 1    1998     2   9147.744891  1.669449  1.000000
# 2    1998     3  12212.238996  2.228715  1.000000
# 3    1998     4  14929.122488  2.724542  1.000000
# 4    1998     5  17426.453955  3.180301  1.000000
# ..    ...   ...           ...       ...       ...
# 107  2013     3  15521.400000  2.216672  1.277876
# 108  2013     4  19022.520000  2.716680  1.277876
# 109  2013     5  22173.480000  3.166681  1.277876
# 110  2013     6  25207.680000  3.600007  1.277876
# 111  2013     7  28008.600000  4.000017  1.277876
#
# [112 rows x 5 columns]

# %% [markdown]
# ### Evolution of poverty thresholds

# %%
pov.pivot_table(values='Yp', index=['ANNO'], columns=['COMP'])
# Out:
# COMP            1             2             3             4             5  \
# ANNO
# 1998  5479.498210   9147.744891  12212.238996  14929.122488  17426.453955
# 1999  5549.157917   9248.596528  12300.633693  15075.209552  17572.336503
# 2000  5833.535612   9722.555222  12930.998260  15847.762967  18472.855542
# 2001  5864.760000   9774.600000  13000.320000  15932.640000  18571.800000
# 2002  5919.600000   9866.040000  13121.880000  16081.680000  18745.440000
# 2003  6298.080000  10496.880000  13960.800000  17109.960000  19944.120000
# 2004  6623.880000  11039.760000  14682.840000  17994.840000  20975.520000
# 2005  6743.400000  11238.960000  14947.800000  18319.560000  21354.000000
# 2006  6986.400000  11644.080000  15486.600000  18979.800000  22123.800000
# 2007  7101.720000  11836.200000  15742.200000  19293.000000  22488.840000
# 2008  7197.600000  11996.040000  15954.720000  19553.520000  22792.440000
# 2009  7077.720000  11796.120000  15688.800000  19227.720000  22412.640000
# 2010  7145.760000  11909.520000  15839.640000  19412.520000  22628.040000
# 2011  7279.440000  12132.360000  16136.040000  19775.760000  23051.520000
# 2012  7134.360000  11890.560000  15814.440000  19381.560000  22592.040000
# 2013  7002.120000  11670.240000  15521.400000  19022.520000  22173.480000
#
# COMP             6             7
# ANNO
# 1998  19667.649656  21963.736462
# 1999  19884.480987  22196.631668
# 2000  21000.722007  23334.130054
# 2001  21113.160000  23459.160000
# 2002  21310.680000  23678.520000
# 2003  22673.280000  25192.560000
# 2004  23845.920000  26495.400000
# 2005  24276.120000  26973.480000
# 2006  25151.160000  27945.840000
# 2007  25566.240000  28406.880000
# 2008  25911.480000  28790.520000
# 2009  25479.600000  28310.640000
# 2010  25724.520000  28582.800000
# 2011  26205.840000  29117.640000
# 2012  25683.600000  28537.320000
# 2013  25207.680000  28008.600000

# %% [markdown]
# ## Combine the datasets and compute poverty classes

# %%
df = pd.merge(rfam, comp, how='left', on=['ANNO','NQUEST'])
# adjust NCOMP to have max 7 categories by components to merge with poverty thresholds
df['COMP'] = df['NCOMP'].mask(df['NCOMP']>7,7)
# combine df with poverty thersholds
df = pd.merge(df, pov, how='left', on=['ANNO','COMP'])
# compute exterme poverty thershold as % of Yp
Yp_perc = .5
df['Yep'] = Yp_perc*df['Yp']
# compute the poverty classes
df['C'] = 2
df['C'] = df['C'].mask(df['Y2']<=df['Yp'], 1)
df['C'] = df['C'].mask(df['Y2']<=df['Yep'], 0)
# compute equivalent incomes and classes
df['Ye'] = df['Y2']/df['Yscale']/df['Tscale']
df['Ce'] = 2

df['Ce'] = df['Ce'].mask(df['Ye']<=pov.loc[0,'Yp'], 1)
df['Ce'] = df['Ce'].mask(df['Ye']<=Yp_perc*pov.loc[0,'Yp'], 0)
df
# Out:
#        ANNO  NQUEST            Y1            Y2  NCOMP  AREA3  A1  A2  A3  A4  \
# 0      1998      34  80050.819359  79761.603495      4      1   2   0   0   2
# 1      1998     123   6197.482789   1323.722054      4      3   2   0   0   2
# 2      1998     173  20761.567343  21034.256586      4      3   2   0   2   0
# 3      1998     304  12911.422477  13820.386620      3      3   1   2   0   0
# 4      1998     325  15803.581112  16236.758806      2      1   0   1   0   1
# ...     ...     ...           ...           ...    ...    ...  ..  ..  ..  ..
# 62965  2012  889749  21778.000000  21956.020998      3      3   1   0   0   0
# 62966  2012  889750  14800.000000  14925.801505      1      1   1   0   0   0
# 62967  2012  889751  26000.000000  26178.020998      2      1   2   0   0   0
# 62968  2012  889752  23100.000000  23131.980055      4      3   2   0   0   2
# 62969  2012  889753  44600.000000  44754.284865      3      3   1   0   0   0
#
#        A5  COMP            Yp    Yscale   Tscale          Yep  C  \
# 0       0     4  14929.122488  2.724542  1.00000  7464.561244  2
# 1       0     4  14929.122488  2.724542  1.00000  7464.561244  0
# 2       0     4  14929.122488  2.724542  1.00000  7464.561244  2
# 3       0     3  12212.238996  2.228715  1.00000  6106.119498  2
# 4       0     2   9147.744891  1.669449  1.00000  4573.872445  2
# ...    ..   ...           ...       ...      ...          ... ..
# 62965   2     3  15814.440000  2.216659  1.30201  7907.220000  2
# 62966   0     1   7134.360000  1.000000  1.30201  3567.180000  2
# 62967   0     2  11890.560000  1.666661  1.30201  5945.280000  2
# 62968   0     4  19381.560000  2.716650  1.30201  9690.780000  2
# 62969   2     3  15814.440000  2.216659  1.30201  7907.220000  2
#
#                  Ye  Ce
# 0      29275.234627   2
# 1        485.851237   0
# 2       7720.291090   2
# 3       6201.056479   2
# 4       9725.816787   2
# ...             ...  ..
# 62965   7607.476317   2
# 62966  11463.663543   2
# 62967  12063.554552   2
# 62968   6539.806048   2
# 62969  15506.778857   2
#
# [62970 rows x 19 columns]

# %% [markdown]
# ## Analysis of trajectories
# ### Filter the dataset to exclude single year income and gaps between years

# %%
# Create a table with all sequence (for filtering df)
Y = df.pivot_table(values='Ye', columns=['ANNO'], index=['NQUEST'])
Y
# Out:
# ANNO            1998          2000          2002          2004          2006  \
# NQUEST
# 34      29275.234627  27435.215612  35283.873183  45105.134705           NaN
# 123       485.851237           NaN           NaN           NaN           NaN
# 173      7720.291090   8341.399201  10083.540404   8069.352246  10654.437571
# 304      6201.056479           NaN           NaN           NaN           NaN
# 325      9725.816787           NaN           NaN           NaN           NaN
# ...              ...           ...           ...           ...           ...
# 889749           NaN           NaN           NaN           NaN           NaN
# 889750           NaN           NaN           NaN           NaN           NaN
# 889751           NaN           NaN           NaN           NaN           NaN
# 889752           NaN           NaN           NaN           NaN           NaN
# 889753           NaN           NaN           NaN           NaN           NaN
#
# ANNO            2008          2010          2012
# NQUEST
# 34               NaN           NaN           NaN
# 123              NaN           NaN           NaN
# 173     15624.923005  15306.150503  38200.452796
# 304              NaN           NaN           NaN
# 325              NaN           NaN           NaN
# ...              ...           ...           ...
# 889749           NaN           NaN   7607.476317
# 889750           NaN           NaN  11463.663543
# 889751           NaN           NaN  12063.554552
# 889752           NaN           NaN   6539.806048
# 889753           NaN           NaN  15506.778857
#
# [34386 rows x 8 columns]

# %%
# get the households index with complete trajectories from 1998 to 2012
nquest_index_full_traj = Y.dropna().index
# filter the dataframe
df = df[df['NQUEST'].isin(nquest_index_full_traj)]
print('Number of housholds with complete trajectories from 1998 to 2012:', len(df['NQUEST'].unique()))
# Out:
# Number of housholds with complete trajectories from 1998 to 2012: 914

# %% [markdown]
# ## Descriptive statistics

# %% [markdown]
# ### Income stats by components

# %%
df.groupby(['COMP'])['Ye'].describe().round(2)
# Out:
#        count      mean       std      min      25%       50%       75%  \
# COMP
# 1     1101.0  15358.05  10539.19     0.00  9164.47  13183.66  18895.25
# 2     2258.0  14995.72   9448.49   784.61  9153.48  13088.55  18421.79
# 3     1702.0  14532.65   9592.02     0.00  8918.06  13012.51  17754.19
# 4     1627.0  12106.83   7529.16     0.00  7306.33  10837.33  14957.06
# 5      490.0  10114.09   5774.25     0.00  5556.53   9615.55  13399.05
# 6      109.0  10323.97   5783.92     0.00  6426.38   9770.16  12791.52
# 7       25.0  14407.41  10798.38  3033.78  8771.85  11224.28  16944.50
#
#             max
# COMP
# 1     200125.84
# 2     222822.47
# 3     112369.43
# 4     101693.05
# 5      35573.93
# 6      37650.18
# 7      56228.42

# %% [markdown]
# ### Income stats by components and year

# %%
df.groupby(['COMP','ANNO'])['Ye'].describe().round(2)
# Out:
#            count      mean       std       min       25%       50%       75%  \
# COMP ANNO
# 1    1998   90.0  14138.35   8816.95    449.02   8747.49  11487.78  18340.42
#      2000  101.0  15142.21   7878.46   1649.38   9314.17  13874.24  19416.73
#      2002  111.0  16404.43  10342.82      0.00   9325.63  13273.21  20678.95
#      2004  128.0  14711.59   8076.07   3143.49   8987.90  13105.41  18781.96
#      2006  136.0  15107.63   9579.92   4078.41   8509.71  12776.31  19114.54
#      2008  160.0  14865.08   9506.58      0.00   9157.24  13177.03  18024.05
#      2010  179.0  16509.03  16377.07    920.18   9711.45  13717.99  19083.78
#      2012  196.0  15383.99   8445.01   3463.88   9268.08  13153.48  18902.16
# 2    1998  203.0  14637.67   9791.52    784.61   8591.43  11974.62  17315.65
#      2000  228.0  14143.71   8656.91   1726.03   8784.43  12454.80  17304.57
#      2002  242.0  14963.10   9023.53   3110.18   9288.89  12798.65  18811.83
#      2004  270.0  14350.52   8069.99   2919.97   8862.22  12592.89  17612.68
#      2006  307.0  15382.19  14071.30   1844.68   9369.78  13167.37  18180.25
#      2008  320.0  14965.72   7626.96   3197.43   9452.97  13445.55  18588.27
#      2010  337.0  15593.04   8652.50   1012.21   9326.07  13977.65  19313.46
#      2012  351.0  15390.88   8132.11   1917.04   9698.22  13692.05  18814.54
# 3    1998  244.0  13317.51   9565.42      0.00   8289.13  11795.54  15982.35
#      2000  229.0  13850.06   7531.43   1832.85   8241.16  13335.95  17702.62
#      2002  231.0  15012.10  10551.42   1818.58   9700.39  12762.60  18159.85
#      2004  219.0  14034.27   9215.03   2239.14   8625.62  12348.76  17176.85
#      2006  210.0  14193.89   8551.54   2122.93   8982.62  12605.47  17362.45
#      2008  196.0  14761.12   8379.55   1442.45   9580.78  13782.21  17821.97
#      2010  192.0  15191.34   8525.47   2263.94   9502.74  14134.64  18221.23
#      2012  181.0  16472.31  13537.39   1713.12   9762.97  14225.45  18880.40
# 4    1998  268.0  11783.78   7808.87      0.00   6974.78  10448.90  14734.23
#      2000  255.0  11604.47   6680.43   1071.42   7255.90  10469.63  14393.76
#      2002  238.0  12299.93   6781.05      0.00   7563.42  11283.56  15422.31
#      2004  214.0  11930.71   7317.48    411.08   7322.75  11021.23  14877.59
#      2006  182.0  12012.99   9051.15   1732.21   7229.61  10460.77  14383.49
#      2008  174.0  12192.64   7546.40   1457.20   7296.52  11020.90  14918.28
#      2010  154.0  13168.36   7794.74   1504.48   7973.34  11603.13  15665.43
#      2012  142.0  12424.31   7523.27      0.00   7288.53  11175.16  15475.81
# 5    1998   90.0   8676.17   5185.59      0.00   4214.46   8695.15  11656.04
#      2000   81.0   9880.23   5625.49    796.61   5443.55   9373.92  12591.47
#      2002   74.0  10739.47   6176.65    175.39   5813.81  10540.16  13922.63
#      2004   66.0  11121.93   5984.75    835.95   5813.90  10885.44  15938.22
#      2006   63.0  10182.98   5567.99   1040.23   5144.20   9357.76  14616.70
#      2008   47.0  10600.05   6841.44      0.00   5729.15  11083.90  13589.49
#      2010   37.0  10037.52   5444.55      0.00   6040.38  10851.78  13457.93
#      2012   32.0  10464.47   5148.57   1350.95   7255.34   9153.87  12837.27
# 6    1998   16.0   8002.68   5055.31   1762.33   5916.86   6480.34  10686.53
#      2000   18.0  10295.98   8565.44      0.00   4998.42   8776.88  11264.25
#      2002   15.0  10419.76   4970.21   3419.76   7702.13   9770.16  12731.20
#      2004   14.0   8896.92   3621.40   3456.35   5915.19   9125.82  11047.53
#      2006   12.0  12591.90   5653.76   6537.13   9291.53  10985.27  13890.55
#      2008   14.0  10948.79   6743.36   3335.14   5914.77   9763.30  13599.92
#      2010   11.0  11413.25   4253.03   4431.89   8551.31  12387.30  14049.64
#      2012    9.0  11239.69   4179.98   4568.12   7428.00  12973.49  14114.71
# 7    1998    3.0  12215.24   4094.74   9671.65   9853.47  10035.29  13487.04
#      2000    2.0  11524.28   7665.35   6104.06   8814.17  11524.28  14234.39
#      2002    3.0  23570.36  28292.76   6487.36   7241.33   7995.29  32111.85
#      2004    3.0  16667.58  13050.05   8771.85   9136.06   9500.27  20615.44
#      2006    4.0  11621.78   5198.55   4976.90   8931.33  12337.90  15028.34
#      2008    3.0  16167.71   4233.87  12414.86  13872.78  15330.70  18044.14
#      2010    4.0  12975.73   6889.40   4032.00   9426.21  14256.53  17806.04
#      2012    3.0  10961.35   7840.14   3033.78   7086.51  11139.23  14925.14
#
#                  max
# COMP ANNO
# 1    1998   53911.90
#      2000   37199.44
#      2002   54574.84
#      2004   40006.81
#      2006   58417.83
#      2008   83096.30
#      2010  200125.84
#      2012   49306.81
# 2    1998   64006.09
#      2000   79841.99
#      2002   74627.41
#      2004   64702.24
#      2006  222822.47
#      2008   45351.46
#      2010   71976.54
#      2012   54825.43
# 3    1998  107014.11
#      2000   53758.93
#      2002  112369.43
#      2004   83560.50
#      2006   86763.38
#      2008   78051.27
#      2010   64188.31
#      2012  108752.97
# 4    1998   83931.46
#      2000   51428.12
#      2002   41127.98
#      2004   69054.14
#      2006  101693.05
#      2008   65137.79
#      2010   45445.39
#      2012   55313.10
# 5    1998   35573.93
#      2000   35264.19
#      2002   30337.12
#      2004   25093.83
#      2006   22411.21
#      2008   34130.77
#      2010   24847.09
#      2012   25021.85
# 6    1998   22528.72
#      2000   37650.18
#      2002   21280.25
#      2004   14891.70
#      2006   27031.69
#      2008   28497.34
#      2010   17842.43
#      2012   15913.83
# 7    1998   16938.78
#      2000   16944.50
#      2002   56228.42
#      2004   31730.60
#      2006   16834.42
#      2008   20757.58
#      2010   19357.84
#      2012   18711.05

# %% [markdown]
# ### Income stats by poverty class

# %%
df.groupby(['Ce'])['Ye'].describe()
# Out:
#      count          mean          std          min          25%           50%  \
# Ce
# 0    119.0   1642.529233   861.559551     0.000000  1049.048459   1832.853002
# 1    479.0   4301.892236   748.278755  2742.807734  3699.023863   4387.651247
# 2   6714.0  14802.988481  9023.689975  5480.918194  9360.715950  12870.518301
#
#              75%            max
# Ce
# 0    2349.971977    2737.982119
# 1    4945.987487    5467.459496
# 2   17698.428174  222822.468181

# %% [markdown]
# ### Income stats by poverty class and year

# %%
df.groupby(['Ce','ANNO'])['Ye'].describe()
# Out:
#          count          mean           std          min          25%  \
# Ce ANNO
# 0  1998   32.0   1390.502020    909.872464     0.000000   702.184782
#    2000   19.0   1948.488429    701.538411     0.000000  1779.443106
#    2002   15.0   1261.422628    936.890028     0.000000   416.690072
#    2004    9.0   1717.321794    817.107627   411.080209   901.497213
#    2006   11.0   2130.894554    579.480245  1040.232351  1788.446086
#    2008   10.0   1595.918426    996.250321     0.000000  1144.945607
#    2010   14.0   1740.082671    853.685723     0.000000  1104.223184
#    2012    9.0   1756.246289    769.509164     0.000000  1713.124150
# 1  1998   76.0   4197.647972    762.442557  2786.464391  3565.833297
#    2000   75.0   4217.301902    727.289823  2870.841504  3672.037631
#    2002   63.0   4265.824061    747.911333  2743.532424  3672.788430
#    2004   72.0   4319.190394    788.291461  2910.886861  3701.203520
#    2006   57.0   4444.678761    714.778368  2742.807734  4020.896933
#    2008   55.0   4295.394504    710.406858  2753.911784  3802.530637
#    2010   30.0   4291.428953    740.918150  2830.531964  3744.930618
#    2012   51.0   4455.345347    780.799298  2803.675110  3829.705812
# 2  1998  806.0  13937.281753   8618.749076  5521.504848  8835.967243
#    2000  820.0  14073.521589   7377.342275  5480.918194  8970.604421
#    2002  836.0  15037.321930   8912.135318  5516.687113  9578.788602
#    2004  833.0  14365.631080   7923.842876  5516.823005  9175.147181
#    2006  846.0  14782.959423  10910.312494  5500.277520  9342.044296
#    2008  849.0  14876.237599   7952.668817  5519.171686  9635.962685
#    2010  870.0  15575.136786  10365.521874  5500.378894  9637.067954
#    2012  854.0  15678.076872   9293.901858  5494.801372  9743.480759
#
#                   50%           75%            max
# Ce ANNO
# 0  1998   1355.053397   2215.865331    2733.858360
#    2000   2028.531179   2445.694901    2713.716684
#    2002   1403.092774   1992.876232    2630.784516
#    2004   2156.739724   2246.603880    2732.032674
#    2006   2352.911613   2605.531742    2653.664237
#    2008   1768.032969   2446.157335    2648.741356
#    2010   1868.379707   2452.296847    2737.982119
#    2012   1809.400385   2170.303276    2702.598767
# 1  1998   4307.311295   4830.172306    5442.191053
#    2000   4188.315314   4831.023234    5443.554580
#    2002   4173.858343   4905.266796    5431.651339
#    2004   4341.153322   4969.780801    5446.651660
#    2006   4670.547218   5010.118080    5466.548329
#    2008   4353.284684   4799.496754    5467.459496
#    2010   4449.339190   4765.404491    5425.045462
#    2012   4615.687591   5146.613286    5445.969362
# 2  1998  11910.251356  16551.301740  107014.106524
#    2000  12461.068895  17035.409308   79841.988492
#    2002  12766.476923  18108.147676  112369.431371
#    2004  12416.790275  17199.283006   83560.501043
#    2006  12648.495630  17424.164074  222822.468181
#    2008  13183.655794  17786.767047   83096.301831
#    2010  13705.605594  18539.611641  200125.836408
#    2012  13756.484361  18618.779636  108752.974953

# %% [markdown]
# ### Percentage of households in each poverty class

# %%
df.groupby(['C'])['Ye'].count()/len(df)
# Out:
# C
# 0    0.016275
# 1    0.065509
# 2    0.918217
# Name: Ye, dtype: float64

# %% [markdown]
# ### Percentage of households in each poverty class by year

# %%
df.groupby(['ANNO','C'])['Ye'].count()/df.groupby(['ANNO'])['Ye'].count()
# Out:
# ANNO  C
# 1998  0    0.035011
#       1    0.083151
#       2    0.881838
# 2000  0    0.020788
#       1    0.082057
#       2    0.897155
# 2002  0    0.016411
#       1    0.068928
#       2    0.914661
# 2004  0    0.009847
#       1    0.078775
#       2    0.911379
# 2006  0    0.012035
#       1    0.062363
#       2    0.925602
# 2008  0    0.010941
#       1    0.060175
#       2    0.928884
# 2010  0    0.015317
#       1    0.032823
#       2    0.951860
# 2012  0    0.009847
#       1    0.055799
#       2    0.934354
# Name: Ye, dtype: float64

# %% [markdown]
# ## Function for indexes computation

# %%
# create multiindex for probability matrix
def P_index(m):
    tuples = []
    for i in range(m):
        for j in range(m):
            tuples.append((i,j))
    index = pd.MultiIndex.from_tuples(tuples, names=['i', 'j'])
    return index

# transition probability matrix
def get_P(df):
    prob = df.copy()
    prob.columns = ['NQUEST','i']
    prob['j'] = prob.groupby('NQUEST')['i'].shift(-1)
    prob = prob.dropna() # eliminate the last obs for each group
    prob['j'] = prob['j'].astype(dtype='int')
    prob = prob[['i','j']]
    prob['p_ij'] = 1
    prob = prob.groupby(['i','j']).count()
    prob['p_ij'] = prob.groupby(prob.index.get_level_values('i'))['p_ij'].transform(lambda x: x/x.sum())
    prob = prob.reindex(P_index(3), fill_value=0)
    P_hat = np.array(prob.iloc[:,0]).reshape(3, 3)
    return P_hat

# computation of the integral for the variance for Gini index

# integral approximation using the discrete distribution with n bins
def integral_gini_sigma(df, nbins=200):
    freq, values = np.histogram(df['Ye'], bins=nbins)
    prob = list(freq/np.sum(freq))
    resy = 0
    for iy, dy in enumerate(values[1:]):
        resx = 0
        for ix, dx in enumerate(values[1:]):
            resx += np.abs(dy-dx)*prob[ix]
        resy += (resx**2)*prob[iy]
    return resy

def integral_gini_sigma2(df, mu, P, nbins=100):    
    P0 = P[:,0]
    P1 = P[:,1]
    mP0 = mu.T.dot(P0)[0]
    mP1 = mu.T.dot(P1)[0]
    
    v = []
    for i in range(2):
        freq, values = np.histogram(df[df['Ce']==i]['Ye'], bins=nbins)
        if np.sum(freq)==0:
            prob = list(freq)
        else:
            prob = list(freq/np.sum(freq))
        if i == 0:
            p0 = prob+[0]*nbins
        elif i == 1:
            p1 = [0]*nbins+prob
        v += list(values[1:])
    resy = 0
    for iy, dy in enumerate(v):
        resx = 0
        for ix, dx in enumerate(v):
            resx += np.abs(dy-dx)*(mP0*p0[ix]+mP1*p1[ix])
        resy += (resx**2)*(mP0*p0[iy]+mP1*p1[iy])
    return resy

def integral_gini(df, nbins=100):
    freq, values = np.histogram(df['Ye'], bins=nbins)
    if np.sum(freq)==0:
        prob = list(freq)
    else:
        prob = list(freq/np.sum(freq))
    prob = [0]+prob
    resy = 0
    for iy, dy in enumerate(values):
        resx = 0
        for ix, dx in enumerate(values):
            resx += np.abs(dy-dx)*prob[ix]*prob[iy]
        resy += resx
    return resy

# computation of the poverty indexes and their variances
def poverty_indexes(P, mu, y, y2, y_p, yx, int_sigma1, int_sigma2):
    mP = mu_1998.T.dot(P)[0]
    # Headcount ratio
    Ht = mP[:2].sum()
    varH = Ht*(1-Ht)
    # Income gap
    It = 1-((y[0]*mP[0]+y[1]*mP[1])/(yp*Ht))
    sigma2_I = y2[0]*mP[0]+y2[1]*mP[1]-(y[0]*mP[0]+y[1]*mP[1])**2
    varI = sigma2_I/(yp*Ht)**2
    # Gini
    Gt_num = mP[0]**2*yx[0] + 2*(y[1]-y[0])*mP[0]*mP[1] + mP[1]**2*yx[1]
    Gt_den = 2*Ht*(y[0]*mP[0]+y[1]*mP[1])
    Gt = Gt_num/Gt_den
    int_sigma = mP[0]**3*int_sigma1+mP[0]**2*mP[1]*(y[0]-y[1])**2+mP[1]**2*mP[0]*(y[0]-y[1])**2+mP[1]**3*int_sigma2
    sigma2_G = int_sigma-Gt_num**2
    varG = sigma2_G/Gt_den**2
    # Sen
    St = Ht*(It+(1-It)*Gt)
    varS = (1-Ht)*St**2/Ht
    return [Ht, It, Gt, St], [varH, varI, varG, varS]

# computation of confidence intervals
def conf_intervals(indexes, var, N, alpha=0.05):
    z = norm.ppf(1-alpha/2)
    # headcount ratio
    H = indexes[0]
    var_H = var[0]
    ci_H = [H+sign*z*np.sqrt(var_H/N) for sign in [-1,1]]
    # Income gap
    I = indexes[1]
    var_I = var[1] 
    ci_I = [I+sign*z*np.sqrt(var_I/N) for sign in [-1,1]]
    # Gini
    G = indexes[2]
    var_G = var[2]
    ci_G = [G+sign*z*np.sqrt(var_G/N) for sign in [-1,1]]
    # Sen
    S = indexes[3]
    var_S = var[3] 
    ci_S = [S+sign*z*np.sqrt(var_S/N) for sign in [-1,1]]
    return [ci_H[0],ci_H[1],ci_I[0],ci_I[1],ci_G[0],ci_G[1],ci_S[0],ci_S[1]]

# computation of the asymptotic indexes
def poverty_indexes_inf(G, y, y_p, yx):
    Pinf = expm(10e9*G)[0]
    Hinf = Pinf[:2].sum()
    Iinf = (yp-y[0])/yp*Pinf[0]/Hinf+(yp-y[1])/yp*Pinf[1]/Hinf
    Ginf = (Pinf[0]**2*yx[0] + 2*(y[1]-y[0])*Pinf[0]*Pinf[1] + Pinf[1]**2*yx[1])/(2*Hinf*(y[0]*Pinf[0]+y[1]*Pinf[1]))
    Sinf = Hinf*(Iinf+(1-Iinf)*Ginf)
    return [Hinf, Iinf, Ginf, Sinf]

# %% [markdown]
# ## Poverty indexes

# %%
P_hat = get_P(df[['NQUEST','Ce']])
print('Transition probability matrix')
print(P_hat)

G_hat = (logm(P_hat)/2) # equation (3.6)
print('Generator Matrix')
print(G_hat)

# estimate initial distribution using only 1998
mu_1998 = np.array(df[df['ANNO']==1998].groupby('Ce')['Ce'].count()/len(df[df['ANNO']==1998])).reshape(3,1)
print('Initial distribution')
print(mu_1998)

y = df.groupby('Ce')['Ye'].mean().tolist()
print('Average income by class:', y)
y2 = (df['Ye']**2).groupby(df['Ce']).mean().tolist()
# use the base threshold for 1 person in 1998
yp = pov.loc[0,'Yp']
print('Poverty threshold:', yp)
print('Extreme Poverty threshold:', Yp_perc*yp)
# save the number of households
hh = len(df['NQUEST'].unique())
print('N:', hh)

# computation of poverty indexes based on generator matrix G and initial ditribution mu
poverty = []
i = []
int_gini = integral_gini(df[(df['Ce']<2)])
int_gini_0 = integral_gini(df[(df['Ce']==0)])
int_gini_1 = integral_gini(df[(df['Ce']==1)])
int_gini_sigma_1 = integral_gini_sigma(df[(df['Ce']==0)])
int_gini_sigma_2 = integral_gini_sigma(df[(df['Ce']==1)])
yx = df.groupby('Ce')['Ye'].apply(lambda s: s.apply(lambda x: np.abs(x-s)).mean().mean()).to_list()
for t in range(1998,2014):
    P = expm((t-1997)*G_hat)
    sub_df = df[(df['Ce']<2)&(df['ANNO']==t)].copy()
#     if not sub_df.empty:
#         int_gini = integral_gini(sub_df)
#         int_gini_0 = integral_gini(sub_df[sub_df['Ce']==0])
#         int_gini_1 = integral_gini(sub_df[sub_df['Ce']==1])
#         int_gini_sigma = integral_gini_sigma(sub_df)
#         int_gini_sigma2 = integral_gini_sigma2(sub_df, mu_1998, P)
#         # variable average income and N (comment out for fixed)

        # compute income average for each class
#         y = sub_df.groupby('Ce')['Ye'].mean().reindex([0,1]).fillna(0).tolist()
        # compute averate of |y-x| for each class
#         yx = df[(df['ANNO']==t)].groupby('Ce')['Ye'].apply(lambda s: s.apply(lambda x: np.abs(x-s)).mean().mean()).to_list()
        # hh = len(df[df['ANNO']==t]['NQUEST'].unique()) # same results as outside the for loop

    I, var = poverty_indexes(P, mu_1998, y, y2, [Yp_perc*yp, yp], yx, int_gini_sigma_1, int_gini_sigma_2)
    CI = conf_intervals(I, var, hh) # hh is the number of households
    # asymptotic indexes
    I_inf = poverty_indexes_inf(G_hat, y, [Yp_perc*yp, yp], yx)
    poverty.append(I+CI+I_inf)
    i.append(t)
poverty = pd.DataFrame(poverty, columns=['H','I','G','S','H_L','H_U','I_L','I_U','G_L','G_U','S_L','S_U','H_inf','I_inf','G_inf','S_inf'], index=i)
# observed indexes
poverty['H_obs'] = (df[df['Ce']<2].groupby(['ANNO'])['Ye'].count()/df.groupby(['ANNO'])['Ye'].count())
poverty['I_obs'] = 1-df[df['Ce']<2].groupby('ANNO')['Ye'].sum()/(yp*df[df['Ce']<2].groupby(['ANNO'])['Ye'].count())
poverty['G_obs'] = df[(df['Ce']<2)].groupby('ANNO').apply(lambda h: h['Ye'].apply(lambda l: np.abs(l-h['Ye']).sum()).sum())/(2*df[df['Ce']<2].groupby(['ANNO'])['Ye'].count()*df[df['Ce']<2].groupby('ANNO')['Ye'].sum())
poverty['S_obs'] = poverty['H_obs']*(poverty['I_obs']+(1-poverty['I_obs'])*poverty['G_obs'])
# interpolate missing observed values
poverty.interpolate(inplace=True)
poverty
# Out:
# Transition probability matrix
# [[0.29090909 0.49090909 0.21818182]
#  [0.07476636 0.44158879 0.48364486]
#  [0.00392491 0.02730375 0.96877133]]
# Generator Matrix
# [[-0.71355111  0.76259072 -0.04903961]
#  [ 0.11504486 -0.49114987  0.37610501]
#  [ 0.00159081  0.02011707 -0.02170788]]
# Initial distribution
# [[0.03501094]
#  [0.08315098]
#  [0.88183807]]
# Average income by class: [1642.5292326576173, 4301.892236089712, 14802.98848149619]
# Poverty threshold: 5479.498210476844
# Extreme Poverty threshold: 2739.749105238422
# N: 914
#              H         I         G         S       H_L       H_U       I_L  \
# 1998  0.107499  0.327851  0.204673  0.050032  0.087418  0.127579  0.192980
# 1999  0.097846  0.313434  0.192176  0.043578  0.078585  0.117108  0.169372
# 2000  0.090020  0.306280  0.185865  0.039178  0.071465  0.108575  0.154466
# 2001  0.083969  0.302474  0.182480  0.036087  0.065989  0.101949  0.144246
# 2002  0.079399  0.300274  0.180514  0.033870  0.061871  0.096926  0.136851
# 2003  0.075986  0.298888  0.179273  0.032262  0.058808  0.093164  0.131338
# 2004  0.073454  0.297952  0.178432  0.031087  0.056541  0.090367  0.127178
# 2005  0.071582  0.297287  0.177835  0.030226  0.054869  0.088295  0.124028
# 2006  0.070200  0.296803  0.177400  0.029593  0.053637  0.086763  0.121649
# 2007  0.069180  0.296444  0.177077  0.029127  0.052729  0.085631  0.119858
# 2008  0.068429  0.296178  0.176838  0.028784  0.052061  0.084797  0.118515
# 2009  0.067875  0.295980  0.176659  0.028531  0.051568  0.084182  0.117513
# 2010  0.067467  0.295833  0.176527  0.028345  0.051206  0.083728  0.116766
# 2011  0.067166  0.295723  0.176428  0.028208  0.050939  0.083394  0.116212
# 2012  0.066945  0.295642  0.176355  0.028107  0.050742  0.083148  0.115801
# 2013  0.066782  0.295582  0.176301  0.028033  0.050597  0.082966  0.115497
#
#            I_U       G_L       G_U       S_L       S_U     H_inf     I_inf  \
# 1998  0.462723  0.173076  0.236271  0.040686  0.059378  0.066325  0.295413
# 1999  0.457497  0.160226  0.224125  0.035000  0.052157  0.066325  0.295413
# 2000  0.458094  0.153119  0.218611  0.031103  0.047254  0.066325  0.295413
# 2001  0.460702  0.148851  0.216109  0.028360  0.043814  0.066325  0.295413
# 2002  0.463697  0.146074  0.214955  0.026393  0.041347  0.066325  0.295413
# 2003  0.466438  0.144149  0.214397  0.024969  0.039556  0.066325  0.295413
# 2004  0.468726  0.142759  0.214105  0.023929  0.038245  0.066325  0.295413
# 2005  0.470546  0.141734  0.213936  0.023169  0.037283  0.066325  0.295413
# 2006  0.471956  0.140971  0.213828  0.022611  0.036575  0.066325  0.295413
# 2007  0.473031  0.140401  0.213754  0.022200  0.036053  0.066325  0.295413
# 2008  0.473841  0.139976  0.213700  0.021899  0.035669  0.066325  0.295413
# 2009  0.474447  0.139659  0.213660  0.021677  0.035386  0.066325  0.295413
# 2010  0.474899  0.139423  0.213630  0.021513  0.035177  0.066325  0.295413
# 2011  0.475234  0.139248  0.213608  0.021393  0.035024  0.066325  0.295413
# 2012  0.475483  0.139119  0.213592  0.021305  0.034910  0.066325  0.295413
# 2013  0.475667  0.139023  0.213579  0.021239  0.034827  0.066325  0.295413
#
#          G_inf     S_inf     H_obs     I_obs     G_obs     S_obs
# 1998  0.176148  0.027825  0.118162  0.385728  0.251355  0.063823
# 1999  0.176148  0.027825  0.110503  0.349885  0.211563  0.054119
# 2000  0.176148  0.027825  0.102845  0.314041  0.171771  0.044415
# 2001  0.176148  0.027825  0.094092  0.320488  0.189446  0.042106
# 2002  0.176148  0.027825  0.085339  0.326936  0.207121  0.039797
# 2003  0.176148  0.027825  0.086980  0.295725  0.180140  0.036611
# 2004  0.176148  0.027825  0.088621  0.264514  0.153160  0.033425
# 2005  0.176148  0.027825  0.081510  0.260837  0.150226  0.030349
# 2006  0.176148  0.027825  0.074398  0.257160  0.147291  0.027272
# 2007  0.176148  0.027825  0.072757  0.274525  0.157588  0.028242
# 2008  0.176148  0.027825  0.071116  0.291889  0.167885  0.029212
# 2009  0.176148  0.027825  0.059628  0.328431  0.197910  0.026875
# 2010  0.176148  0.027825  0.048140  0.364972  0.227935  0.024538
# 2011  0.176148  0.027825  0.056893  0.312883  0.196212  0.024820
# 2012  0.176148  0.027825  0.065646  0.260794  0.164488  0.025102
# 2013  0.176148  0.027825  0.065646  0.260794  0.164488  0.025102

# %% [markdown]
# ### expected values by groups

# %% [markdown]
# $\int_0^{+\infty}xdF(x)$

# %%
kde = sm.nonparametric.KDEUnivariate(df[(df['Ce']<2)]['Ye'])
kde.fit(bw=50) # Estimate the densities
f = lambda x: x*kde.evaluate(x)
integrate.quad(f, 0, yp)
# Out:
# (3735.8756100001383, 4.8704644946610874e-05)

# %%
freq, values = np.histogram(df[(df['Ce']<2)]['Ye'], bins=2000)
if np.sum(freq)==0:
    prob = list(freq)
else:
    prob = list(freq/np.sum(freq))
prob = [0]+prob
res = 0
for ix, dx in enumerate(values):
    res += dx*prob[ix]
res
# Out:
# 3774.0419178794746

# %%
df[(df['Ce']<2)]['Ye'].mean()
# Out:
# 3772.6878925973742

# %%
# expected value of group 0
kde = sm.nonparametric.KDEUnivariate(df[(df['Ce']==0)]['Ye'])
kde.fit(bw=50) # Estimate the densities
f = lambda x: x*kde.evaluate(x)
integrate.quad(f, 0, Yp_perc*yp)
# Out:
# (1586.9675745974478, 1.808686824468527e-05)

# %%
freq, values = np.histogram(df[(df['Ce']==0)]['Ye'], bins=2000)
if np.sum(freq)==0:
    prob = list(freq)
else:
    prob = list(freq/np.sum(freq))
prob = [0]+prob
res = 0
for ix, dx in enumerate(values):
    res += dx*prob[ix]
res
# Out:
# 1643.2264281129364

# %%
df[(df['Ce']==0)]['Ye'].mean()
# Out:
# 1642.5292326576173

# %%
# expected value of group 1
kde = sm.nonparametric.KDEUnivariate(df[(df['Ce']==1)]['Ye'])
kde.fit(bw=50) # Estimate the densities
f = lambda x: x*kde.evaluate(x)
integrate.quad(f, Yp_perc*yp, yp)
# Out:
# (4245.4496379099855, 5.250018719920414e-05)

# %%
freq, values = np.histogram(df[(df['Ce']==1)]['Ye'], bins=2000)
if np.sum(freq)==0:
    prob = list(freq)
else:
    prob = list(freq/np.sum(freq))
prob = [0]+prob
res = 0
for ix, dx in enumerate(values):
    res += dx*prob[ix]
res
# Out:
# 4302.568480073157

# %%
df[(df['Ce']==1)]['Ye'].mean()
# Out:
# 4301.892236089713

# %% [markdown]
# ### Double integral

# %% [markdown]
# $\int_0^{+\infty}\int_0^{+\infty}|y-x|dF(x)dF(y)$

# %%
yp
# Out:
# 5479.498210476844

# %%
df.groupby(['ANNO','Ce'])['Ye'].count()
# Out:
# ANNO  Ce
# 1998  0      32
#       1      76
#       2     806
# 2000  0      19
#       1      75
#       2     820
# 2002  0      15
#       1      63
#       2     836
# 2004  0       9
#       1      72
#       2     833
# 2006  0      11
#       1      57
#       2     846
# 2008  0      10
#       1      55
#       2     849
# 2010  0      14
#       1      30
#       2     870
# 2012  0       9
#       1      51
#       2     854
# Name: Ye, dtype: int64

# %%
y
# Out:
# [1642.5292326576173, 4301.892236089712, 14802.98848149619]

# %%
df[(df['Ce']<2)]['Ye'].hist(bins=30)

# %%
freq, values = np.histogram(df[(df['Ce']<2)&(df['ANNO']==1998)]['Ye'], bins=200)
if np.sum(freq)==0:
    prob = list(freq)
else:
    prob = list(freq/np.sum(freq))
prob = [0]+prob
resy = 0
for iy, dy in enumerate(values):
    for ix, dx in enumerate(values):
        resy += np.abs(dy-dx)*prob[ix]*prob[iy]
resy
# Out:
# 1690.172652774434

# %%
kde = sm.nonparametric.KDEUnivariate(df[(df['Ce']<2)]['Ye'])
kde.fit(bw=50, cut=0) # Estimate the densities
f = lambda y, x: np.abs(y-x)*kde.evaluate(x)*kde.evaluate(y)
integrate.dblquad(f, 0, yp, 0, yp)
# Out:
# (1338.5201480845922, 1.887852241813341e-05)

# %%
df[(df['Ce']<2)]['Ye'].apply(lambda x: np.abs(x-df[(df['Ce']<2)]['Ye'])).mean().mean()
# Out:
# 1437.1501941275562

# %% [markdown]
# ### double integral decomposed

# %% [markdown]
# $(\mu'\mathbf{P}_{.1}(t))^2\int_0^{y_{ep}}\int_0^{y_{ep}}|y-x|dF_1(x)dF_1(y)+ 2(y_2-y_1)(\mu'\mathbf{P}_{.1}(t))(\mu'\mathbf{P}_{.2}(t))+(\mu'\mathbf{P}_{.2}(t))^2\int_{y_{ep}}^{y_{p}}\int_{y_{ep}}^{y_{p}}|y-x|dF_2(x)dF_2(y)$

# %%
freq, values = np.histogram(df[(df['Ce']==0)]['Ye'], bins=100)
if np.sum(freq)==0:
    prob = list(freq)
else:
    prob = list(freq/np.sum(freq))
prob = [0]+prob
resy_1 = 0
for iy, dy in enumerate(values):
    for ix, dx in enumerate(values):
        resy_1 += np.abs(dy-dx)*prob[ix]*prob[iy]
print(resy_1)
yx_1 = df[(df['Ce']==0)]['Ye'].apply(lambda x: np.abs(x-df[(df['Ce']==0)]['Ye'])).mean().mean()
print(yx_1)

freq, values = np.histogram(df[(df['Ce']==1)]['Ye'], bins=100)
if np.sum(freq)==0:
    prob = list(freq)
else:
    prob = list(freq/np.sum(freq))
prob = [0]+prob
resy_2 = 0
for iy, dy in enumerate(values):
    for ix, dx in enumerate(values):
        resy_2 += np.abs(dy-dx)*prob[ix]*prob[iy]
print(resy_2)
yx_2 = df[(df['Ce']==1)]['Ye'].apply(lambda x: np.abs(x-df[(df['Ce']==1)]['Ye'])).mean().mean()
print(yx_2)

t=1998
P = expm((t-1997)*G_hat)
mP = mu_1998.T.dot(P)[0]
y1 = df[(df['Ce']==0)]['Ye'].mean()
y2 = df[(df['Ce']==1)]['Ye'].mean()
y3 = df[(df['Ce']==2)]['Ye'].mean()
print(mP[0]**2*resy_1 + 2*(y2-y1)*mP[0]*mP[1] + mP[1]**2*resy_2)
print(mP[0]**2*yx_1 + 2*(y2-y1)*mP[0]*mP[1] + mP[1]**2*yx_2)
# Out:
# 958.8215779886683
# 962.9054371384652
# 859.4096561450165
# 859.1413609956678
# 17.42147995757135
# 17.422210272735377

# %%
y2-y1
# Out:
# 2659.363003432096

# %%
mP[0]**2
# Out:
# 0.0006257906496797816

# %%
mP
# Out:
# array([0.02501581, 0.08248287, 0.89250132])

# %%
kde = sm.nonparametric.KDEUnivariate(df[(df['Ce']==0)&(df['ANNO']==1998)]['Ye'])
kde.fit(bw=50) # Estimate the densities
f = lambda y, x: np.abs(y-x)*kde.evaluate(x)*kde.evaluate(y)
int_0 = integrate.dblquad(f, 0, Yp_perc*yp, 0, Yp_perc*yp)[0]
print(int_0)

kde = sm.nonparametric.KDEUnivariate(df[(df['Ce']==1)&(df['ANNO']==1998)]['Ye'])
kde.fit(bw=50) # Estimate the densities
f = lambda y, x: np.abs(y-x)*kde.evaluate(x)*kde.evaluate(y)
int_1 = integrate.dblquad(f, Yp_perc*yp, yp, Yp_perc*yp, yp)[0]
print(int_1)

t=1998
P = expm((t-1997)*G_hat)
mP = mu_1998.T.dot(P)[0]
y1 = df[(df['Ce']==0)&(df['ANNO']==t)]['Ye'].mean()
y2 = df[(df['Ce']==1)&(df['ANNO']==t)]['Ye'].mean()
mP[0]**2*int_0 + 2*(y2-y1)*mP[0]*mP[1] + mP[1]**2*int_1
# Out:
# 764.6065306442813
# 854.2425582269474
# 23.64750786196764

# %%
t=1998
nbins = 100
freq, values = np.histogram(df[(df['Ce']<2)&(df['ANNO']==t)]['Ye'], bins=nbins)
test = pd.DataFrame(zip(freq, values[1:]), columns=['p','value'])
test['p']=test['p']/test['p'].sum()
integral = test.apply(lambda x: (np.abs(x['value']-test['value'])*test['p']*x['p']).sum(), axis=1).sum()
integral_square = (test.apply(lambda x: (np.abs(x['value']-test['value'])*test['p']).sum()**2, axis=1)*test['p']).sum()
print(integral, integral_square)

freq, values = np.histogram(df[(df['Ce']==0)&(df['ANNO']==t)]['Ye'], bins=nbins)
test = pd.DataFrame(zip(freq, values[1:]), columns=['p','value'])
test['p']=test['p']/test['p'].sum()
integral_0 = test.apply(lambda x: (np.abs(x['value']-test['value'])*test['p']*x['p']).sum(), axis=1).sum()
integral_square_0 = (test.apply(lambda x: (np.abs(x['value']-test['value'])*test['p']).sum()**2, axis=1)*test['p']).sum()
print(integral_0, integral_square_0)

freq, values = np.histogram(df[(df['Ce']==1)&(df['ANNO']==t)]['Ye'], bins=nbins)
test = pd.DataFrame(zip(freq, values[1:]), columns=['p','value'])
test['p']=test['p']/test['p'].sum()
integral_1 = test.apply(lambda x: (np.abs(x['value']-test['value'])*test['p']*x['p']).sum(), axis=1).sum()
integral_square_1 = (test.apply(lambda x: (np.abs(x['value']-test['value'])*test['p']).sum()**2, axis=1)*test['p']).sum()
print(integral_1, integral_square_1)

P = expm((t-1997)*G_hat)
mP = mu_1998.T.dot(P)[0]
y1 = df[(df['Ce']==0)&(df['ANNO']==t)]['Ye'].mean()
y2 = df[(df['Ce']==1)&(df['ANNO']==t)]['Ye'].mean()
numerator = mP[0]**2*integral_0 + 2*(y2-y1)*mP[0]*mP[1] + mP[1]**2*integral_1
print(numerator, numerator**2)
# Out:
# 1686.4073508373906 3151503.7665884253
# 1018.3622390661875 1090040.6104041096
# 870.8631647815653 798543.6955794292
# 23.99622213485633 575.8186767453687

# %% [markdown]
# ### double integral with squared

# %%
freq, values = np.histogram(df[(df['Ce']<2)&(df['ANNO']==1998)]['Ye'], bins=100)
if np.sum(freq)==0:
    prob = list(freq)
else:
    prob = list(freq/np.sum(freq))
prob = [0]+prob
resy = 0
for iy, dy in enumerate(values):
    resx = 0
    for ix, dx in enumerate(values):
        resx += np.abs(dy-dx)*prob[ix]
    resy += resx**2*prob[iy]
resy
# Out:
# 3151503.7665884253

# %%
kde = sm.nonparametric.KDEUnivariate(df[(df['Ce']<2)&(df['ANNO']==1998)]['Ye'])
kde.fit(bw=50) # Estimate the densities
integrate.quad(lambda y: integrate.quad(lambda x: np.abs(y-x)*kde.evaluate(x), 0, yp)[0]**2*kde.evaluate(y), 0, yp)
# Out:
# (2632272.866252748, 0.023342826465943867)

# %% [markdown]
# ### triple integral

# %%
kde = sm.nonparametric.KDEUnivariate(df[(df['Ce']<2)&(df['ANNO']==1998)]['Ye'])
kde.fit() # Estimate the densities
f = lambda x, y, z: np.abs(y-x)*np.abs(y-z)*kde.evaluate(x)*kde.evaluate(y)*kde.evaluate(z)
integrate.nquad(f, [[0,yp], [0,yp], [0,yp]])

# %%
freq, values = np.histogram(df[(df['Ce']<2)&(df['ANNO']==1998)]['Ye'], bins=100)
if np.sum(freq)==0:
    prob = list(freq)
else:
    prob = list(freq/np.sum(freq))
prob = [0]+prob
resy = 0
for iy, dy in enumerate(values):
    for ix, dx in enumerate(values):
        for iz, dz in enumerate(values):
            resy += np.abs(dy-dx)*np.abs(dy-dz)*prob[ix]*prob[iy]*prob[iz]
resy
# Out:
# 3151503.7665884076

# %%
for t in range(1998,2014):
    P = expm((t-1997)*G_hat)
    print(t, mu_1998.T.dot(P)[0])
# Out:
# 1998 [0.02748357 0.09720369 0.87531274]
# 1999 [0.0236533  0.10482417 0.87152253]
# 2000 [0.02172719 0.10903341 0.8692394 ]
# 2001 [0.02077702 0.11141626 0.86780673]
# 2002 [0.02032322 0.11280798 0.8668688 ]
# 2003 [0.02011887 0.11365169 0.86622943]
# 2004 [0.02003743 0.11418478 0.86577778]
# 2005 [0.02001458 0.11453615 0.86544927]
# 2006 [0.02001801 0.11477715 0.86520484]
# 2007 [0.02003181 0.11494829 0.8650199 ]
# 2008 [0.02004845 0.11507328 0.86487828]
# 2009 [0.02006452 0.11516656 0.86476892]
# 2010 [0.02007871 0.1152373  0.86468398]
# 2011 [0.02009067 0.11529156 0.86461776]
# 2012 [0.0201005 0.1153335 0.864566 ]
# 2013 [0.02010844 0.1153661  0.86452546]

# %%
(df.groupby(['ANNO','Ce'])['Ce'].count()/df.groupby('ANNO')['Ce'].count()).to_frame().unstack()
# Out:
#             Ce
# Ce           0         1         2
# ANNO
# 1998  0.035011  0.083151  0.881838
# 2000  0.021882  0.097374  0.880744
# 2002  0.019694  0.080963  0.899344
# 2004  0.021882  0.135667  0.842451
# 2006  0.022976  0.134573  0.842451
# 2008  0.021882  0.135667  0.842451
# 2010  0.020788  0.110503  0.868709
# 2012  0.018600  0.107221  0.874179

# %% [markdown]
# ## Plots

# %%
for i, title in {'H':'Headcount Ratio','I':'Income Gap','G':'Gini Index','S':'Sen Index'}.items():
    ax = poverty[[i+'_obs',i,i+'_U',i+'_L',i+'_inf']].ffill().plot(figsize=(10,10), style={i+'_obs':'--',i:'-',i+'_L':'-.',i+'_U':'-.',i+'_inf':':'},
                                                              title=title)
    ax.legend(('Observed '+title, title, 'CI 95% Upper bound', 'CI 95% Lower bound', 'Asymptotic '+title))
    ax.fill_between(poverty.index, poverty[i+'_U'], poverty[i+'_L'], alpha=0.1)
    ax.set_xlabel('Year')
    ax.set_ylim([0,df[i+'_U'].max()*1.3])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'H_U'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-b4a5380afdd1> in <module>
#       5     ax.fill_between(poverty.index, poverty[i+'_U'], poverty[i+'_L'], alpha=0.1)
#       6     ax.set_xlabel('Year')
# ----> 7     ax.set_ylim([0,df[i+'_U'].max()*1.3])
#
# ~/env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'H_U'
